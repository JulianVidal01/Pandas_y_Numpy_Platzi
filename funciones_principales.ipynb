# %%
import numpy as np

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([ 2, 15,  5, 10, 13,  1, 15, 15,  3,  2])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 2, 15,  5, 10, 13],
#        [ 1, 15, 15,  3,  2]])

# %%
arr
# Out:
# array([ 2, 15,  5, 10, 13,  1, 15, 15,  3,  2])

# %%
arr.max()
# Out:
# 15

# %%
matriz
# Out:
# array([[ 2, 15,  5, 10, 13],
#        [ 1, 15, 15,  3,  2]])

# %%
matriz.max(0)
# Out:
# array([ 2, 15, 15, 10, 13])

# %%
arr.argmax() #Indice donde se encuentra el valor mas grande de nuestro array
# Out:
# 1

# %%
matriz.argmax() #Indice donde se encuentra el valor mas grande de nuestro array
# Out:
# 1

# %%
arr.min() #valor minimo de la funcion
# Out:
# 1

# %%
matriz.min(0)
# Out:
# array([ 1, 15,  5,  3,  2])

# %%
arr.argmin()
# Out:
# 5

# %%
matriz.argmin()
# Out:
# 5

# %%
arr.ptp()
# Out:
# 14

# %%
matriz.ptp(0) #Distacia del mayor al menor
# Out:
# array([ 1,  0, 10,  7, 11])

# %%
np.percentile(arr,50)
# Out:
# 7.5

# %%
np.median(arr)
# Out:
# 7.5

# %%
np.percentile(matriz,50,0)
# Out:
# array([ 1.5, 15. , 10. ,  6.5,  7.5])

# %%
np.median(matriz,0)
# Out:
# array([ 1.5, 15. , 10. ,  6.5,  7.5])

# %%
np.std(arr)
# Out:
# 5.752390807307862

# %%
np.var(arr)
# Out:
# 33.089999999999996

# %%
arr.sort()
arr
# Out:
# array([ 1,  2,  2,  3,  5, 10, 13, 15, 15, 15])

# %%
np.mean(arr)
# Out:
# 8.1

# %%
np.mean(matriz,1)
# Out:
# array([ 2.6, 13.6])

# %%
a = np.array([[1,2],[3,4]])
b = np.array([5,6])

# %%
a.ndim
b.ndim
# Out:
# 1

# %%
b = np.expand_dims(b,axis=0)

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
np.concatenate((a,b.T),axis=1) #Con T mayuscula podemos hacer la transpuesta
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])
