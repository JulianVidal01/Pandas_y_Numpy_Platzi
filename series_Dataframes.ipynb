# %%
import pandas as pd

# %%
psg_players = pd.Series(['Navas','Mbapee','Neymar','Messi'],index=[1,7,10,30])

# %%
psg_players
# Out:
# 1      Navas
# 7     Mbapee
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players = pd.Series(['Navas','Mbapee','Neymar','Messi'])

# %%
dict = {1:'Navas',7:'Mbappe',10:'Neymar',30:'Messi'}

# %%
dict
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[1]
# Out:
# 'Navas'

# %%
psg_players[0:3]
# Out:
# 0     Navas
# 1    Mbapee
# 2    Neymar
# dtype: object

# %%
dict = {'Jugador':['Navas','Mbapee','Neymar','Messi'],'altura':[183.0,170.0,170.0,165.0],'Goles':[2,200,200,200]}

# %%
df_players = pd.DataFrame(dict,index=[1,7,10,30])

# %%
df_players.columns
# Out:
# Index(['Jugador', 'altura', 'Goles'], dtype='object')

# %%
df_players.index
# Out:
# Int64Index([1, 7, 10, 30], dtype='int64')

# %% [markdown]
# ##RETO

# %%
players = pd.read_csv('https://static.platzi.com/media/public/uploads/jugadores_granadacf-1_65f23f9c-1c4a-4ca0-b303-eaee8ee7aed5.txt',header=None, sep=',')

# %%
df_gp = pd.DataFrame(players)

# %%
df_gp.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')
