# %%
import pandas as pd

# %%
df_books = pd.read_csv('/content/drive/MyDrive/PLATZI/Curso Básico de Manipulación y Transformación de Datos con Pandas y NumPy/bestsellers-with-categories.csv',sep=',')
#Para serpara un archivo distinto a comas se utiliza el siguiente codigo sep='' por el digito de separación
#Header sirve para informar en que posición se encuentra el archivo, en caso de que no tenga header se coloca none.

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.columns #Muestra el nombre de las columnas
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
pd.read_json('/content/drive/MyDrive/PLATZI/Curso Básico de Manipulación y Transformación de Datos con Pandas y NumPy/hpcharactersdataraw.json',typ='series')

#Typ= indexar
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %% [markdown]
# #RETO

# %%
ig = pd.read_csv('/content/drive/MyDrive/PLATZI/Curso Básico de Manipulación y Transformación de Datos con Pandas y NumPy/data_account.csv')

# %%
ig.columns
# Out:
# Index(['rank', 'name', 'channel_Info', 'Category', 'Posts', 'Followers',
#        'Avg. Likes', 'Eng Rate'],
#       dtype='object')

# %%
ig.Followers
# Out:
# 0      580.1M
# 1      519.9M
# 2      403.7M
# 3      375.9M
# 4      365.3M
#         ...
# 195     35.4M
# 196     35.3M
# 197     35.1M
# 198       35M
# 199     34.9M
# Name: Followers, Length: 200, dtype: object
