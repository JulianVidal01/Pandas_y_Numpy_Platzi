# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[7, 9],
#        [7, 2],
#        [3, 5]])

# %%
arr.shape # Shape, cuantas filas y cuantas columnas tenemos
# Out:
# (3, 2)

# %%
arr.reshape(1,6) #Cambiar la forma de la matriz
# Out:
# array([[7, 9, 7, 2, 3, 5]])

# %%
arr.reshape(2,3)
# Out:
# array([[7, 9, 7],
#        [2, 3, 5]])

# %%
np.reshape(arr,(1,6)) #Otra manera de hacer el reshape
# Out:
# array([[7, 9, 7, 2, 3, 5]])

# %%
arr #Arreglo original
# Out:
# array([[7, 9],
#        [7, 2],
#        [3, 5]])

# %%
np.reshape(arr,(2,3),'C') #Array en lenguaje C
# Out:
# array([[7, 9, 7],
#        [2, 3, 5]])

# %%
np.reshape(arr,(2,3),'F') #Array en lenguaje Fortant
# Out:
# array([[7, 3, 2],
#        [7, 9, 5]])

# %%
np.reshape(arr,(2,3),'A') #Guardado en el sistema
# Out:
# array([[7, 9, 7],
#        [2, 3, 5]])

# %% [markdown]
# No se puede cambiar por dejar de respetar la forma original, esto quiere decir que la cantidad de valores

# %%
arr = np.random.randint(1,100,(5,9))
arr
# Out:
# array([[54, 45, 40, 43, 41, 83, 44, 98, 57],
#        [ 7, 30, 98, 27, 84, 99, 10, 15, 24],
#        [ 5, 80, 80, 62,  8, 16, 94, 29, 60],
#        [57, 71, 96, 89, 18, 22, 12, 89, 12],
#        [67, 61, 95, 96, 91, 18, 22, 25, 96]])

# %%
np.reshape(arr,(9,5),'C') #Array en lenguaje C
# Out:
# array([[54, 45, 40, 43, 41],
#        [83, 44, 98, 57,  7],
#        [30, 98, 27, 84, 99],
#        [10, 15, 24,  5, 80],
#        [80, 62,  8, 16, 94],
#        [29, 60, 57, 71, 96],
#        [89, 18, 22, 12, 89],
#        [12, 67, 61, 95, 96],
#        [91, 18, 22, 25, 96]])

# %%
np.reshape(arr,(2,3),'C') #Array en lenguaje C que no se puede compilar
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-57f9918e3730> in <module>
# ----> 1 np.reshape(arr,(2,3),'C') #Array en lenguaje C
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/overrides.py in reshape(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#     299
#     300
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 45 into shape (2,3)
